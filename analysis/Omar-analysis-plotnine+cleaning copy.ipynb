# %% [markdown]
# # Analysis of scraped Immoweb data - The Chainsmokers

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
#import re

# %%
immo = pd.read_csv('../data/clean/details_clean.csv')
#immo = pd.read_csv('../../immo-eliza-analysis-the_chaincoders/details_clean.csv')

pd.set_option('display.max_columns', None) # Displays all the columns
# Out:
# C:\Users\Omar\AppData\Local\Temp\ipykernel_10324\677958950.py:1: DtypeWarning: Columns (88,105,106,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   immo = pd.read_csv('../data/clean/details_clean.csv')

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Here we are:
# * changing *numpy not a number* type to *None* type
# * removing some rows which either shouldn't be here (annuity properties) or need further implementation in the scraper (group developments)
# * removing substrings to clean up columns for type casting
# * displaying the first 5 columns of the dataframe

# %%
immo = immo.replace(np.nan, None)


# Replace 'Not specified' with None as in this case it serves no purpose. If a consumption is not provided it might as well be absent
immo['Primary energy consumption'] = immo['Primary energy consumption'].replace('Not specified', None)
immo['CO₂ emission'] = immo['CO₂ emission'].replace('Not specified', None)
immo['Yearly theoretical total energy consumption'] = immo['Yearly theoretical total energy consumption'].replace('Not specified', None)


# Remove annuity properties
substring = '€'
filter = immo['Price'].str.contains(substring)
immo = immo[~filter]


# Remove group developments for dataset
immo = immo[
    (immo["Subtype_of_property"] != "New-real-estate-project-houses")
    & (immo["Subtype_of_property"] != "New-real-estate-project-apartments")
]


# Remove substrings from strings
immo['Price'] = immo['Price'].str.replace(r'Starting price : ','')
immo['CO₂ emission'] = immo['CO₂ emission'].str.replace(r' kg CO₂/m²','')
immo['Yearly theoretical total energy consumption'] = immo['Yearly theoretical total energy consumption'].str.replace(r' kWh/year','')
immo['Building price excluding VAT'] = immo['Building price excluding VAT'].str.replace(r'€','')
immo['Building price excluding VAT'] = immo['Building price excluding VAT'].str.replace(r',','')
immo['Total price including taxes*'] = immo['Total price including taxes*'].str.replace(r'€','')
immo['Total price including taxes*'] = immo['Total price including taxes*'].str.replace(r',','')
immo['Street frontage width'] = immo['Street frontage width'].str.replace(r' m','')

# Remove 'Unnamed: 0' column as that seems to just be a key column generated from 'raw' data
immo.drop(columns='Unnamed: 0', inplace=True)

immo.head()
# Out:
#    Property_ID  Locality   Price Subtype_of_property Type_of_property  \
# 1     11135548     Ronse  259000               Villa            House
# 6     11135545  Zottegem  645000               Villa            House
# 7     11135101   Seraing  329000  Mixed-use-building            House
# 8     11135086   Beersel  379000          Town-house            House
# 9     11134157  Tongeren  169000               House            House
#
#            Available as of Neighbourhood or locality Outdoor parking spaces  \
# 1   After signing the deed          Vlaamse Ardennen                    5.0
# 6   After signing the deed           Oost-Vlaanderen                    4.0
# 7   After signing the deed                      None                    6.0
# 8  Depending on the tenant            Sud  Bruxelles                    1.0
# 9   After signing the deed            Liège environs                    1.0
#
#   Primary energy consumption Energy class Reference number of the EPC report  \
# 1                        471            E                            3033404
# 6                        462            E          20230818-0002967446-RES-1
# 7                        418            E                     20240112001720
# 8                        665            F                      Not specified
# 9                        523            F          20210429-0002407652-RES-1
#
#   CO₂ emission Yearly theoretical total energy consumption  \
# 1         8899                                        None
# 6         None                                        None
# 7         None                                       72247
# 8          193                                        None
# 9         2388                                        None
#
#    Planning permission obtained  Subdivision permit  \
# 1                             0                   0
# 6                             0                   0
# 7                             0                   0
# 8                             1                   0
# 9                             0                   0
#
#    Possible priority purchase right  \
# 1                                 0
# 6                                 0
# 7                                 0
# 8                                 1
# 9                                 0
#
#   Proceedings for breach of planning regulations Flood zone type  \
# 1                                             No  Non flood zone
# 6                                           None  Non flood zone
# 7                                             No  Non flood zone
# 8                                             No  Non flood zone
# 9                                             No  Non flood zone
#
#    Tenement building                Address Website External reference  \
# 1                  0       Stationstraat 30    None            5847455
# 6                  0      Sint-Denijslaan 1    None            5863623
# 7                  1     Rue J. Wettinck 49    None            5863385
# 8                  0   av. de la Floride 77    None            5847271
# 9                  0  Rue de la Wallonie 2A    None            5707493
#
#   Postcode                                                Url  \
# 1   9600.0  https://www.immoweb.be/en/classified/villa/for...
# 6   9620.0  https://www.immoweb.be/en/classified/villa/for...
# 7   4100.0  https://www.immoweb.be/en/classified/mixed-use...
# 8   1653.0  https://www.immoweb.be/en/classified/town-hous...
# 9   3700.0  https://www.immoweb.be/en/classified/house/for...
#
#             Available date Construction year Number of floors  \
# 1   May 20 2024 - 12:00 AM            1959.0              2.0
# 6                     None            1976.0              1.0
# 7                     None            1900.0              2.0
# 8    May 1 2024 - 12:00 AM            1979.0              2.0
# 9  March 1 2024 - 12:00 AM            1930.0              2.0
#
#   Building condition Street frontage width Number of frontages  \
# 1        To renovate                    10                 3.0
# 6               Good                    18                 4.0
# 7        To renovate                    12                 2.0
# 8               Good                     6                 2.0
# 9               Good                     6                 3.0
#
#   Covered parking spaces Surroundings type Living area    Kitchen type  \
# 1                    1.0          Isolated       165.0   Semi equipped
# 6                    2.0             Urban       272.0       Installed
# 7                    1.0          Isolated       110.0   Not installed
# 8                    1.0          Isolated       160.0  Hyper equipped
# 9                   None          Isolated       165.0       Installed
#
#   Bedrooms Bedroom 1 surface Bedroom 2 surface Bedroom 3 surface Bathrooms  \
# 1      3.0              14.0              12.0               8.0       1.0
# 6      4.0              17.0              17.0              15.0       1.0
# 7      5.0              12.0              18.0              15.0       4.0
# 8      3.0              17.0              16.0              10.0       1.0
# 9      4.0              17.0              16.0              15.0       1.0
#
#   Toilets  Basement  Attic  Furnished Surface of the plot  \
# 1     1.0         1      1          0               674.0
# 6     2.0         0      0          0              2627.0
# 7     4.0         0      0          0              1640.0
# 8     1.0         1      0          0               650.0
# 9     1.0         0      0          0               442.0
#
#   Width of the lot on the street Garden surface Terrace surface As built plan  \
# 1                           None          351.0            30.0            No
# 6                           None         2327.0            26.0          None
# 7                           None          465.0            45.0            No
# 8                           None          240.0            35.0          None
# 9                           None          360.0            19.0            No
#
#   Heating type  Double glazing Total ground floor buildable  \
# 1          Gas               1                         95.0
# 6     Fuel oil               1                         None
# 7          Gas               1                       1170.0
# 8     Fuel oil               0                         65.0
# 9     Fuel oil               1                        123.0
#
#                  Latest land use designation Cadastral income  \
# 1                 Area of landscape interest             None
# 6  Living area (residential, urban or rural)             None
# 7  Living area (residential, urban or rural)             None
# 8                                       None             None
# 9  Living area (residential, urban or rural)             None
#
#   Living room surface Kitchen surface Bedroom 4 surface Office surface  \
# 1                None            None              None           None
# 6                53.0            28.0              14.0           12.0
# 7                23.0            13.0               9.0           25.0
# 8                40.0             6.0              None           None
# 9                17.0            15.0              12.0           12.0
#
#    Office Connection to sewer network  Dining room Bedroom 5 surface  \
# 1       0                        None            0              None
# 6       1                   Connected            0              None
# 7       1                   Connected            1              18.0
# 8       0                   Connected            0              None
# 9       1                   Connected            1              None
#
#   Shower rooms Armored door  Gas, water & electricity Virtual visit  \
# 1         None         None                         0          None
# 6         None         None                         0          None
# 7          4.0          Yes                         1          None
# 8          1.0         None                         0          None
# 9          1.0         None                         0          None
#
#   Basement surface Dressing room Professional space Attic surface  \
# 1             None          None               None          None
# 6             None          None               None          None
# 7             None          None               None          None
# 8             None          None               None          None
# 9             20.0          None               None          None
#
#   Land is facing street Wooded land Plot at rear  Flat land  \
# 1                  None        None         None          0
# 6                  None        None         None          0
# 7                  None        None         None          0
# 8                  None        None         None          0
# 9                  None        None         None          0
#
#   Garden orientation Terrace orientation  \
# 1               None                None
# 6               None                None
# 7               None                None
# 8               None                None
# 9               None                None
#
#   Conformity certification for fuel tanks Heat pump Photovoltaic solar panels  \
# 1                                    None      None                      None
# 6                                    None      None                      None
# 7                                    None      None                      None
# 8                                    None      None                      None
# 9                                    None      None                      None
#
#    Thermic solar panels Common water heater Type of building  Terrace  \
# 1                     0                None             None        0
# 6                     0                None             None        0
# 7                     0                None             None        0
# 8                     0                None             None        0
# 9                     0                None             None        0
#
#    Laundry room Isolated Obligation to build Unnamed: 86 Agent's name E-mail  \
# 1             0     None                None        None         None   None
# 6             0     None                None        None         None   None
# 7             0     None                None        None         None   None
# 8             0     None                None        None         None   None
# 9             0     None                None        None         None   None
#
#   Phone number Floor  Garden E-level (overall energy performance) Living room  \
# 1         None  None       0                                 None        None
# 6         None  None       0                                 None        None
# 7         None  None       0                                 None        None
# 8         None  None       0                                 None        None
# 9         None  None       0                                 None        None
#
#   Property name Sea view Building price excluding VAT  \
# 1          None     None                         None
# 6          None     None                         None
# 7          None     None                         None
# 8          None     None                         None
# 9          None     None                         None
#
#   Land price excluding taxes Building VAT Taxes related to land  \
# 1                       None         None                  None
# 6                       None         None                  None
# 7                       None         None                  None
# 8                       None         None                  None
# 9                       None         None                  None
#
#   Total price including taxes* How many fireplaces?  \
# 1                         None                 None
# 6                         None                 None
# 7                         None                 None
# 8                         None                 None
# 9                         None                 None
#
#   Professional space surface Monthly charges Number of annexes  \
# 1                       None            None              None
# 6                       None            None              None
# 7                       None            None              None
# 8                       None            None              None
# 9                       None            None              None
#
#   EPC description Extra information Percentage rented Current monthly revenue  \
# 1            None              None              None                    None
# 6            None              None              None                    None
# 7            None              None              None                    None
# 8            None              None              None                    None
# 9            None              None              None                    None
#
#   Value of the property Lump sum Monthly annuity Indexed annuity  \
# 1                  None     None            None            None
# 6                  None     None            None            None
# 7                  None     None            None            None
# 8                  None     None            None            None
# 9                  None     None            None            None
#
#   Reversionary annuity Bare ownership sale Number of annuitants  \
# 1                 None                None                 None
# 6                 None                None                 None
# 7                 None                None                 None
# 8                 None                None                 None
# 9                 None                None                 None
#
#   Age of annuitant Maximum duration of annuity Age of annuitants  \
# 1             None                        None              None
# 6             None                        None              None
# 7             None                        None              None
# 8             None                        None              None
# 9             None                        None              None
#
#   Venue of the sale Single session Terms of visit
# 1              None           None           None
# 6              None           None           None
# 7              None           None           None
# 8              None           None           None
# 9              None           None           None

# %% [markdown]
# Here we define some lists with the various column names which we will be type casting. This is because some of our numerical values are strings, so we just want to be sure that they are numerical

# %%
map_to_float = [
    "Price",
    "Number of floors",
    "Number of frontages",
    "Covered parking spaces",
    "Outdoor parking spaces",
    "Living area",
    "Bedrooms",
    "Bedroom 1 surface",
    "Bedroom 2 surface",
    "Bedroom 3 surface",
    "Bedroom 4 surface",
    "Bedroom 5 surface",
    "Bathrooms",
    "Toilets",
    "Surface of the plot",
    "Width of the lot on the street",
    "Garden surface",
    "Terrace surface",
    "CO₂ emission",
    "Yearly theoretical total energy consumption",
    "Total ground floor buildable",
    "Cadastral income",
    "Shower rooms",
    "Living room surface",
    "Kitchen surface",
    "Office surface",
    "Basement surface",
    "Attic surface",
    "E-level (overall energy performance)",
    "How many fireplaces?",
    "Floor",
    "Professional space surface",
    "Number of annexes",
    "Building price excluding VAT",
    "Number of annuitants",
    "Age of annuitant",
    "Maximum duration of annuity",
    "Percentage rented",
    "Current monthly revenue",
    "Construction year",
    "Postcode",
    "Street frontage width",
    "Monthly charges",
    "Primary energy consumption"
]

map_to_binary = [
    "As built plan",
    "Connection to sewer network",
    "Armored door",
    "Dressing room",
    "Virtual visit",
    "Professional space",
    "Proceedings for breach of planning regulations",
    "Land is facing street",
    "Wooded land",
    "Plot at rear",
    "Heat pump",
    "Photovoltaic solar panels",
    "Common water heater",
    "Living room",
    "Garden",
    "Isolated",
    "Obligation to build",
    "Indexed annuity",
    "Reversionary annuity",
    "Bare ownership sale",
    "Sea view",
    "Single session"
]

immo[map_to_float] = immo[map_to_float].astype(float).round(2)

# %%
immo[map_to_float] = immo[map_to_float].astype(float).round(2)

# %% [markdown]
# Here we perform the type casting

# %% [markdown]
# Here we will remove empty columns

# %%
print(immo.columns)

immo.dropna(how='all', axis=1, inplace=True)

print(immo.columns)
# Out:
# Index(['Property_ID', 'Locality', 'Price', 'Subtype_of_property',
#        'Type_of_property', 'Available as of', 'Neighbourhood or locality',
#        'Outdoor parking spaces', 'Primary energy consumption', 'Energy class',
#        ...
#        'Indexed annuity', 'Reversionary annuity', 'Bare ownership sale',
#        'Number of annuitants', 'Age of annuitant',
#        'Maximum duration of annuity', 'Age of annuitants', 'Venue of the sale',
#        'Single session', 'Terms of visit'],
#       dtype='object', length=121)
# Index(['Property_ID', 'Locality', 'Price', 'Subtype_of_property',
#        'Type_of_property', 'Available as of', 'Neighbourhood or locality',
#        'Outdoor parking spaces', 'Primary energy consumption', 'Energy class',
#        ...
#        'Taxes related to land', 'Total price including taxes*',
#        'How many fireplaces?', 'Professional space surface',
#        'Number of annexes', 'EPC description', 'Extra information',
#        'Percentage rented', 'Current monthly revenue', 'Single session'],
#       dtype='object', length=104)

# %% [markdown]
# ## Testing cells below

# %%
pd.set_option("display.max_rows", None)

# %%
# Doesn't work

binary_list = []
for column in immo.columns:
    if len(immo[column].value_counts()) == 2:
        binary_list.append(column)
print(len(binary_list), '\n', binary_list)

immo[binary_list] = immo[binary_list].add_suffix(' (0/1)')


binary_list = []
for column in immo.columns:
    if len(immo[column].value_counts()) == 2:
        binary_list.append(column)
print(len(binary_list), '\n', binary_list)
# Out:
# 30
#  ['Type_of_property', 'Planning permission obtained', 'Subdivision permit', 'Possible priority purchase right', 'Proceedings for breach of planning regulations', 'Tenement building', 'Basement', 'Attic', 'Furnished', 'As built plan', 'Double glazing', 'Office', 'Connection to sewer network', 'Dining room', 'Armored door', 'Gas, water & electricity', 'Dressing room', 'Professional space', 'Land is facing street', 'Wooded land', 'Plot at rear', 'Flat land', 'Heat pump', 'Photovoltaic solar panels', 'Thermic solar panels', 'Common water heater', 'Terrace', 'Laundry room', 'Obligation to build', 'Garden']
# 30
#  ['Type_of_property', 'Planning permission obtained', 'Subdivision permit', 'Possible priority purchase right', 'Proceedings for breach of planning regulations', 'Tenement building', 'Basement', 'Attic', 'Furnished', 'As built plan', 'Double glazing', 'Office', 'Connection to sewer network', 'Dining room', 'Armored door', 'Gas, water & electricity', 'Dressing room', 'Professional space', 'Land is facing street', 'Wooded land', 'Plot at rear', 'Flat land', 'Heat pump', 'Photovoltaic solar panels', 'Thermic solar panels', 'Common water heater', 'Terrace', 'Laundry room', 'Obligation to build', 'Garden']

# %%
immo.columns
# Out:
# Index(['Property_ID', 'Locality', 'Price', 'Subtype_of_property',
#        'Type_of_property', 'Available as of', 'Neighbourhood or locality',
#        'Outdoor parking spaces', 'Primary energy consumption', 'Energy class',
#        ...
#        'Taxes related to land', 'Total price including taxes*',
#        'How many fireplaces?', 'Professional space surface',
#        'Number of annexes', 'EPC description', 'Extra information',
#        'Percentage rented', 'Current monthly revenue', 'Single session'],
#       dtype='object', length=104)

# %% [raw]
# #immo[map_to_float] = immo[map_to_float].fillna(-999999)
#
#
# for i in map_to_str:
#     print(i)
#     immo[i] = immo[i].astype(str)
#
# #immo[map_to_float] = immo[map_to_float].replace(-999999, None)

# %% [raw]
# immo["E-level (overall energy performance)"].value_counts()

# %% [raw]
# a = immo[immo["Postcode"] == 'None']
# a[['Property_ID', 'Postcode']]

# %% [raw]
# # Loop over columns to find out which ones are empty
# #len(immo["Number of annuitants"].value_counts())

# %% [raw]
# columns = immo.columns
#
# for column in immo.columns:
#     immo_test = immo[immo[column] == 'None']
#     print(column)
#     print(immo_test,'\n')
# #immo = immo[(immo["Subtype_of_property"] != "New-real-estate-project-houses")]
# #print(columns)

# %% [markdown]
# ## Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#immo.corr(numeric_only=True)

# %% [raw]
# isnull_sum = immo.isnull().sum()
# isnull_mean = immo.isnull().mean()
#
# print(isnull_sum)
# print('_______________________________________________________________')
# print(isnull_mean)

# %%
immo.isnull().mean().plot.bar(figsize=(16,8))
plt.ylabel('Percentage of missing values')
plt.xlabel('Variables')
plt.title('Quantifying missing data')
# Out:
# Text(0.5, 1.0, 'Quantifying missing data')

# %%
high_missing = immo.isnull().mean()
high_missing = high_missing[high_missing > 0.9] # Only plot features with more than 25% values missing

high_missing.plot.bar(figsize=(16,8))

plt.ylabel('Percentage of missing values')
plt.xlabel('Variables')
plt.title('Quantifying missing data')
# Out:
# Text(0.5, 1.0, 'Quantifying missing data')

# %% [raw]
# nulls = immo.isnull().mean()
# cutoff = 0.9
#
# fig, axes = plt.subplots(2, 1, figsize=(16, 20))
#
# #fig.suptitle('Quantifying missing data')
#
# #sns.boxplot(ax=axes[0, 0], data=pokemon, x='Generation', y='Attack')
# nulls.plot.bar(ax=axes[0])
# nulls[nulls > cutoff].plot.bar(ax=axes[1])
#
#
# #plt.ylabel('Percentage of missing values')
# #plt.xlabel('Variables')
# #plt.title('Quantifying missing data')
# axes[0].set_title('Quantifying missing data', fontsize = 18)
# axes[1].set_title(f'Quantifying missing data: Only displaying features with percentages > {cutoff}', fontsize = 18)
#
#
# fig.tight_layout(h_pad=2)
# axes[0].set_xlabel('Features'); axes[1].set_xlabel('Features')
# axes[0].set_ylabel('Proportion of missing values'); axes[1].set_ylabel('Proportion of missing values')
#
# plt.show()

# %%
# Go through list and plot bar plots

# %% [markdown]
# # Answering the questions

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>How many observations and features do you have?</b>
# </div>

# %%
print(f'Number of properties: {immo.shape[0]}')
print(f'Number of initial features: {immo.shape[1]}')
# Out:
# Number of properties: 17585
# Number of initial features: 104

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>What is the proportion of missing values per column?</b>
# </div>

# %%
missing_proportion = immo.isnull().mean()

# Condition
#missing_proportion = missing_proportion[missing_proportion > 0.9] # Only plot features with more than 90% values missing

missing_proportion.plot.bar(figsize=(16,8))

plt.ylabel('Proportion of missing values')
plt.xlabel('Variables')
plt.title('Quantifying missing data')

plt.show()

# Print series

#print(immo.isnull().mean())

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Which variables would you delete and why?</b>
#
# 1. All the empty columns (which has already been done)
# 2. The values below because they make up 5% or less of the data and so are not very useful during the overall analysis
# </div>

# %%
missing_proportion = missing_proportion[missing_proportion > 0.95]
print(missing_proportion)
# Out:
# Terrace orientation                        0.966449
# Conformity certification for fuel tanks    0.962354
# Isolated                                   0.991925
# Agent's name                               0.970145
# E-mail                                     0.999943
# Phone number                               0.972363
# Property name                              0.977993
# Sea view                                   0.996361
# How many fireplaces?                       0.950753
# Professional space surface                 0.974296
# Number of annexes                          0.990844
# EPC description                            0.998976
# Extra information                          0.998294
# Percentage rented                          0.998749
# Current monthly revenue                    0.997043
# Single session                             0.997214
# dtype: float64

# %%
# Dropping the above mentioned columns

names = missing_proportion[missing_proportion > 0.95].index

immo.drop(columns=names, inplace=True)

print(immo.columns, len(immo.columns))

immo.drop(columns='Building price excluding VAT', inplace=True) # Has the same values as Price, but more missing values
# Out:
# Index(['Property_ID', 'Locality', 'Price', 'Subtype_of_property',
#        'Type_of_property', 'Available as of', 'Neighbourhood or locality',
#        'Outdoor parking spaces', 'Primary energy consumption', 'Energy class',
#        'Reference number of the EPC report', 'CO₂ emission',
#        'Yearly theoretical total energy consumption',
#        'Planning permission obtained', 'Subdivision permit',
#        'Possible priority purchase right',
#        'Proceedings for breach of planning regulations', 'Flood zone type',
#        'Tenement building', 'Address', 'External reference', 'Postcode', 'Url',
#        'Available date', 'Construction year', 'Number of floors',
#        'Building condition', 'Street frontage width', 'Number of frontages',
#        'Covered parking spaces', 'Surroundings type', 'Living area',
#        'Kitchen type', 'Bedrooms', 'Bedroom 1 surface', 'Bedroom 2 surface',
#        'Bedroom 3 surface', 'Bathrooms', 'Toilets', 'Basement', 'Attic',
#        'Furnished', 'Surface of the plot', 'Garden surface', 'Terrace surface',
#        'As built plan', 'Heating type', 'Double glazing',
#        'Total ground floor buildable', 'Latest land use designation',
#        'Living room surface', 'Kitchen surface', 'Bedroom 4 surface',
#        'Office surface', 'Office', 'Connection to sewer network',
#        'Dining room', 'Bedroom 5 surface', 'Shower rooms', 'Armored door',
#        'Gas, water & electricity', 'Basement surface', 'Dressing room',
#        'Professional space', 'Attic surface', 'Land is facing street',
#        'Wooded land', 'Plot at rear', 'Flat land', 'Garden orientation',
#        'Heat pump', 'Photovoltaic solar panels', 'Thermic solar panels',
#        'Common water heater', 'Type of building', 'Terrace', 'Laundry room',
#        'Obligation to build', 'Unnamed: 86', 'Floor', 'Garden',
#        'E-level (overall energy performance)', 'Living room',
#        'Building price excluding VAT', 'Land price excluding taxes',
#        'Building VAT', 'Taxes related to land',
#        'Total price including taxes*'],
#       dtype='object') 88

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>What variables are most subject to outliers?</b>
# </div>

# %%
sns.boxplot(x=immo['Price'], y=immo['Subtype_of_property'])
# Out:
# <Axes: xlabel='Price', ylabel='Subtype_of_property'>

# %%
immo.plot(kind='box')
# Out:
# <Axes: >

# %%
# Resize the graph size
plt.figure(figsize=(20,10))
plt.ticklabel_format(style='plain', axis='x')

# Math and display the Mode, Median and Mean
mean = immo['Price'].mean()
median = immo['Price'].median()
mode = immo['Price'].mode()[0]

plt.axvline(mean, color='r', linewidth=3,label='Mean')
plt.axvline(median, color='b', linestyle='dashed', linewidth=3,label='Median')
plt.axvline(mode, color='k', linestyle='dashed', linewidth=3,label='Mode')

# Label the axis
plt.xlabel('Price')
plt.ylabel('house/apartment number')
plt.legend()

# Show the graph
ax = sns.displot(immo['Price'])

mean=round(mean)
median=round(median)
mode=round(mode)

print(f"Mean: {round(mean)} - Median: {round(median)} - Mode: {round(mode)}")
plt.savefig('price.svg', dpi=300)
# Out:
# C:\Users\Omar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Mean: 488172 - Median: 350000 - Mode: 299000

# %%
skew = immo['Price'].skew()
kurtosis = immo['Price'].kurt()

print(f"Skew: {skew} - Kurtosis: {kurtosis}")
# Out:
# Skew: 6.759886878846267 - Kurtosis: 74.0955291864722

# %%
# Create a new column 'Price in millions'
immo['Price (millions)'] = immo['Price'] / 1000000

# Print the outliers horizontally
plt.figure(figsize=(20,3))
sns.boxplot(x=immo["Price (millions)"]);

# %%
# Calculate interquartile range and outliers
Q1 = immo['Price'].quantile(0.25)
Q3 = immo['Price'].quantile(0.75)
IQR = Q3 - Q1

# Define outliers
outliers = immo[(immo['Price'] < Q1 - 1.5 * IQR) | (immo['Price'] > Q3 + 1.5 * IQR)]

# Calculate the upper whisker
upper_whisker = immo['Price'][immo['Price'] <= Q3 + 1.5 * IQR].max()

print(upper_whisker)
print(f'Interquartile range: {IQR}')
print(f'Outliers:\n{outliers.shape}')
# Out:
# 829000.0
# Interquartile range: 236000.0
# Outliers:
# (578, 90)

# %% [markdown]
# Observation
# There are a lot of houses that are sold abvoe 1 million EUR, which are outliers.

# %%
from scipy import stats

# %%
# Remove the outliers
index = immo[(immo['Price'] >= 829000)].index
immo.drop(index, inplace=True)

# Apply Boxcox operation to reduce the skrewness
corrected_price = stats.boxcox(immo['Price'])[0]
immo['price_corrected'] = pd.Series(corrected_price)

skew = immo['price_corrected'].skew()
kurtosis = immo['price_corrected'].kurt()
print(f"Skew: {skew} - Kurtosis: {kurtosis}")
# Out:
# Skew: 0.010779251186043639 - Kurtosis: 0.0027505740960256375

# %%
# Resize the graph size
plt.figure(figsize=(20,10))
#plt.ticklabel_format(style='plain', axis='x')

# Math and display the Mode, Median and Mean
mean = immo['price_corrected'].mean()
median = immo['price_corrected'].median()
mode = immo['price_corrected'].mode()[0]


plt.axvline(mean, color='r', linewidth=3,label='Mean')
plt.axvline(median, color='b', linestyle='dashed', linewidth=3,label='Median')
plt.axvline(mode, color='k', linestyle='dashed', linewidth=3,label='Mode')

# Label the axis
plt.xlabel('Price')
plt.ylabel('house/apartment number')
plt.legend()

# Show the graph
ax = sns.displot(immo['price_corrected'])

print(f"Mean: {round(mean)} - Median: {round(median)} - Mode: {round(mode)}")
plt.savefig('price_corrected.svg', dpi=300)
# Out:
# C:\Users\Omar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Mean: 58 - Median: 58 - Mode: 57

# %%
# Check the price distribution

plt.figure(figsize=(20,5))

plt.title("Distribution of Price")
plt.xlabel("Number of Occurences")
plt.ylabel("Price");

ax = sns.scatterplot(x=range(immo.shape[0]), y=immo["price_corrected"].values)

# %%
print(f'Quantitative values: {len(map_to_float)}')
print(f'Qualitative values: {immo.shape[1] - len(map_to_float)}')
print(immo.shape)
# Out:
# Quantitative values: 44
# Qualitative values: 43
# (17585, 87)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>What is the correlation between the variables and the price? Why do you think some variables are more correlated than others?</b>
# </div>

# %%
plt.figure(figsize=(8, 12))

heatmap = sns.heatmap(immo.corr(numeric_only=True)[['Price']].sort_values(by='Price', ascending=False), vmin=-1, vmax=1, annot=True)

heatmap.set_title('Features Correlating with Price', fontdict={'fontsize':18}, pad=16);

# %%
#print(immo[['Price', 'Building price excluding VAT']])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>How are the variables themselves correlated to each other? Can you find groups of variables that are correlated together?</b>
# </div>

# %%
plt.figure(figsize=(40, 18))

# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.

heatmap = sns.heatmap(immo.corr(numeric_only=True), vmin=-1, vmax=1, annot=True)

# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
binary_list = []
for column in immo.columns:
    if len(immo[column].value_counts()) == 2:
        binary_list.append(column)
print(len(binary_list), '\n',binary_list)


for i in range(len(binary_list)):
    immo[binary_list[i]].value_counts(sort=False).plot.bar().set_title(f'{binary_list[i]}')

    plt.show()
# Out:
# 30
#  ['Type_of_property', 'Planning permission obtained', 'Subdivision permit', 'Possible priority purchase right', 'Proceedings for breach of planning regulations', 'Tenement building', 'Basement', 'Attic', 'Furnished', 'As built plan', 'Double glazing', 'Office', 'Connection to sewer network', 'Dining room', 'Armored door', 'Gas, water & electricity', 'Dressing room', 'Professional space', 'Land is facing street', 'Wooded land', 'Plot at rear', 'Flat land', 'Heat pump', 'Photovoltaic solar panels', 'Thermic solar panels', 'Common water heater', 'Terrace', 'Laundry room', 'Obligation to build', 'Garden']

# %%
# Useful columns
values_list = ['Subtype_of_property', 'Type_of_property', 'Available as of', 'Outdoor parking spaces',
               'Energy class', 'Flood zone type']
for column in immo[values_list]:
    immo[column].value_counts(sort=False).plot.bar().set_title(f'{column}')
    plt.show()

# %% [markdown]
# # Preprocessing

# %% [raw]
# # This is for preprocessing
#
# # Should "Construction year" be categorical or numeric?
# # Deal with "Unnamed: 85/90" or whatever number it happens to be
# # Check "Building VAT"
# # Check "EPC description"
# # Check EPC
#
#
# map_to_int = [
#     "Price",
#     "Number of floors",
#     "Number of frontages",
#     "Covered parking spaces",
#     "Outdoor parking spaces",
#     "Living area",
#     "Bedrooms",
#     "Bedroom 1 surface",
#     "Bedroom 2 surface",
#     "Bedroom 3 surface",
#     "Bedroom 4 surface",
#     "Bedroom 5 surface",
#     "Bathrooms",
#     "Toilets",
#     "Surface of the plot",
#     "Width of the lot on the street",
#     "Garden surface",
#     "Terrace surface",
#     "CO₂ emission",
#     "Yearly theoretical total energy consumption",
#     "Total ground floor buildable",
#     "Cadastral income",
#     "Shower rooms",
#     "Living room surface",
#     "Kitchen surface",
#     "Office surface",
#     "Basement surface",
#     "Attic surface",
#     "E-level (overall energy performance)",
#     "How many fireplaces?",
#     "Floor",
#     "Professional space surface",
#     "Number of annexes",
#     "Building price excluding VAT",
#     "Number of annuitants",
#     "Age of annuitant",
#     "Maximum duration of annuity",
#     "Percentage rented",
#     "Current monthly revenue",
#     "Construction year",
#     "Postcode"
# ]
#
# map_to_float = [
#     "Street frontage width",
#     "Monthly charges",
#     "Primary energy consumption",
# ]
#
# map_to_str = [
#     "Property_ID",
#     #"Construction year",
#     #"Postcode",
#     #"Property name"
# ]
# # Still need to do
#
# map_to_binary = [
#     "As built plan",
#     "Connection to sewer network",
#     "Armored door",
#     "Dressing room",
#     "Virtual visit",
#     "Professional space",
#     "Proceedings for breach of planning regulations",
#     "Land is facing street",
#     "Wooded land",
#     "Plot at rear",
#     "Heat pump",
#     "Photovoltaic solar panels",
#     "Common water heater",
#     "Living room",
#     "Garden",
#     "Isolated",
#     "Obligation to build",
#     "Indexed annuity",
#     "Reversionary annuity",
#     "Bare ownership sale",
#     "Sea view",
#     "Single session"
# ]
#
# # Still need to do
#
# map_to_datetime = ["Available date"]

# %% [markdown]
# Here we perform the type casting

# %% [raw]
# # This is for preprocessing
#
# # Map every column in map_to_int to int
#
# immo[map_to_int] = immo[map_to_int].fillna(-999999)
# immo[map_to_int] = immo[map_to_int].astype(int)
# immo[map_to_int] = immo[map_to_int].replace(-999999, None)
#
# # Map every colmmn in map_to_float to float
# # (and round to 2 decimals because "Primary energy consumption" was in scientific notation)
#
# immo[map_to_float] = immo[map_to_float].astype(float).round(2)
#
#
# # Map every column in map_to_str to string
# # Not sure if 'Property name' should be kept/mapped, as some names are just '1', '3' and now 'None'
#
# immo[map_to_str] = immo[map_to_str].astype(str)
# immo['Postcode'] = immo['Postcode'].replace('None', None) # Should not be a string
#
# # Need to map date time
