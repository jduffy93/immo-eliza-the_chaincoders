# %%
from src.scraper_BS import Scraper

# %%
if __name__ == "__main__":
    
    list_of_urls = [
        "https://www.immoweb.be/en/classified/apartment-block/for-sale/forest/1190/11120343",
        "https://www.immoweb.be/en/classified/house/for-sale/faimes/4317/11109944",
        "https://www.immoweb.be/en/classified/villa/for-sale/woluwe-saint-lambert/1200/11118328",
        "https://www.immoweb.be/en/classified/bungalow/for-sale/waterloo/1410/11122971"
    ]

    scraper = Scraper()

    scraper.listing_listings()

    #for url in scraper.list_of_urls:
    for url in list_of_urls:
        scraper.check_status(url)

        #print(url)
        scraper.listing_details() # Beautifulsoup
    
    scraper.clean_data()
# Out:
# 120
#           Available as of               Available date  \
# 0  After signing the deed  September 1 2023 - 12:00 AM
# 1  After signing the deed                         None
# 2  After signing the deed       May 16 2024 - 12:00 AM
# 3  After signing the deed                         None
#
#   Neighbourhood or locality Construction year Building condition  \
# 0                 Bruxelles              1902               Good
# 1                      None              2007             As new
# 2          Stockel - Woluwé              1930             As new
# 3            Faubourg Ouest              1967               Good
#
#   Street frontage width Number of frontages  \
# 0                   6 m                   2
# 1                  13 m                   4
# 2                10.6 m                   4
# 3                13.5 m                   4
#
#                            Surroundings type Virtual visit Living area  \
# 0  Living area (residential, urban or rural)                       261
# 1                                       None          None         150
# 2                                   Isolated          None         366
# 3  Living area (residential, urban or rural)          None         104
#
#   Living room surface Dining room    Kitchen type Bedrooms Bedroom 1 surface  \
# 0                  70         Yes   USA installed        7                16
# 1                  36         Yes       Installed        3                27
# 2                 120        None  Hyper equipped        5                30
# 3                  22         Yes       Installed        3                15
#
#   Bedroom 2 surface Bedroom 3 surface Bedroom 4 surface Bedroom 5 surface  \
# 0                12                10                16                10
# 1                16                15              None              None
# 2                18                18                12                12
# 3                12                 9              None              None
#
#   Bathrooms Shower rooms Toilets Office surface Office Basement surface  \
# 0         3            1       3             18    Yes               40
# 1         2         None       2             10    Yes             None
# 2         3            4       5             15    Yes             None
# 3         1            1       1           None   None             None
#
#   Furnished Surface of the plot Width of the lot on the street  \
# 0        No                 295
# 1      None                 826                           None
# 2        No                2243
# 3        No                 504                           None
#
#   Connection to sewer network Gas, water & electricity Garden surface  \
# 0                   Connected                      Yes            145
# 1                        None                       No            530
# 2                   Connected                      Yes           1800
# 3                   Connected                      Yes           None
#
#   Terrace surface Primary energy consumption Energy class  \
# 0              20                        468            G
# 1            None                        146            B
# 2             100                        208            D
# 3              37                        584            G
#
#   Reference number of the EPC report   CO₂ emission  \
# 0                      Not specified   94 kg CO₂/m²
# 1                     20231204022779   35 kg CO₂/m²
# 2          20231006-00006557720-01-3   44 kg CO₂/m²
# 3                     20240205005930  110 kg CO₂/m²
#
#   Yearly theoretical total energy consumption Heating type Double glazing  \
# 0                               Not specified          Gas            Yes
# 1                              33580 kWh/year     Fuel oil            Yes
# 2                               Not specified          Gas            Yes
# 3                               Not specified          Gas            Yes
#
#   Total ground floor buildable Subdivision permit  \
# 0                          130                 No
# 1                         None               None
# 2                          580               None
# 3                         None               None
#
#   Possible priority purchase right  \
# 0                               No
# 1                             None
# 2                             None
# 3                             None
#
#   Proceedings for breach of planning regulations Flood zone type  \
# 0                                             No  Non flood zone
# 1                                           None            None
# 2                                           None  Non flood zone
# 3                                           None  Non flood zone
#
#                  Latest land use designation Cadastral income  \
# 0  Living area (residential, urban or rural)
# 1                                       None
# 2                                       None
# 3  Living area (residential, urban or rural)
#
#   Tenement building                   Address Website External reference  \
# 0               Yes         Place Communale 8                    5840923
# 1                No       Place du Parc 87/89               22995 - 2223
# 2                No         Avenue Delleur, 8                    5840138
# 3                No  Chaussée de Tervuren 186    None               None
#
#   Property_ID Postcode Covered parking spaces Outdoor parking spaces  \
# 0    11120343     1190                   None                   None
# 1    11109944     4317                      2                      4
# 2    11118328     1200                   None                      2
# 3    11122971     1410                      1                      1
#
#   How many fireplaces? Basement Garden orientation Terrace As built plan  \
# 0                 None     None               None    None          None
# 1                    1      Yes              South     Yes            No
# 2                 None      Yes               None    None          None
# 3                 None     None               East    None          None
#
#   Kitchen surface Attic Thermic solar panels Laundry room Flat land Garden  \
# 0            None  None                 None         None      None   None
# 1            None  None                 None         None      None   None
# 2             224   Yes                  Yes         None      None   None
# 3               8   Yes                 None          Yes       Yes    Yes
#
#   Conformity certification for fuel tanks Planning permission obtained
# 0                                    None                         None
# 1                                    None                         None
# 2                                    None                         None
# 3                                      No                          Yes
